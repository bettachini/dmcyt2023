# %% [markdown]
# ## Importamos librerias

# %%
# Para visualización en notebook
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_context('poster')
mpl.rcParams['figure.figsize'] = (8,6)
import os

# Números y Datos
import numpy as np
import pandas as pd

import networkx as nx

from glob import glob
from pathlib import Path

# %%
try:
    import powerlaw
except:
    # !pip install powerlaw
    import powerlaw
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting powerlaw
#   Downloading powerlaw-1.5-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from powerlaw) (1.11.2)
# Requirement already satisfied: numpy in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from powerlaw) (1.24.3)
# Requirement already satisfied: matplotlib in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from powerlaw) (3.8.0)
# Collecting mpmath
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 3.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: contourpy>=1.0.1 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from matplotlib->powerlaw) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/vbettachini/bin/jupyter/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->powerlaw) (1.16.0)
# Installing collected packages: mpmath, powerlaw
# Successfully installed mpmath-1.3.0 powerlaw-1.5

# %% [markdown]
# ## Bajamos datos
# ### Primero datos de sujetos

# %%
from pathlib import Path
if not Path("./DataSujetos").is_dir():
  ! wget -q https://www.dropbox.com/s/eei6gnw10o20mcn/DataSujetos.zip?dl=1 -O DataSujetos.zip
  ! unzip -q DataSujetos
  ! rm DataSujetos.zip

# %%
if not Path("./aal_extended_withCoords.csv").exists():
  ! wget -q "https://www.dropbox.com/scl/fi/pu1qdch4c3khk0uol9l0w/aal_extended_withCoords.csv?rlkey=bsnfot3b9ycp7slble59e1cws&dl=1n" -O aal_extended_withCoords.csv

# %% [markdown]
# ### Luego atlas
#
# #### Son 116 regiones cerebrales
# La columna "1" indica el nombre de la subregión, la columna "3" indica a qué región cerebral pertenece, la columna "4" en qué hemisferio se localiza (L=izquierda, R=derecham, --= está en la línea media), las columnas "5", "6" y "7" indican las coordenadas x, y, z de cada subregión

# %%
RegionsNames = pd.read_csv("aal_extended_withCoords.csv", header=None).iloc[:,1:]
RegionsNames
# Out:
#                      1     2          3   4   5   6   7
# 0         Precentral_L  2001    Central   L -39  -6  51
# 1         Precentral_R  2002    Central   R  41  -8  52
# 2        Frontal_Sup_L  2101    Frontal   L -18  35  42
# 3        Frontal_Sup_R  2102    Frontal   R  22  31  44
# 4    Frontal_Sup_Orb_L  2111    Frontal   L -17  47 -13
# ..                 ...   ...        ...  ..  ..  ..  ..
# 111           Vermis_6  9130  Cerebelum  --   2 -67 -15
# 112           Vermis_7  9140  Cerebelum  --   2 -72 -25
# 113           Vermis_8  9150  Cerebelum  --   2 -64 -34
# 114           Vermis_9  9160  Cerebelum  --   2 -55 -35
# 115          Vermis_10  9170  Cerebelum  --   1 -46 -32
#
# [116 rows x 7 columns]

# %% [markdown]
# #### Lista de archivos
# Tenemos varios sujetos para 4 condiciones, una correspondiente a vigilia y 3 a diferentes estadios del sueño no REM (*rapid eye movement*):<br>
#
# "W": despierto ("Wake")
# <br> "N1": sueño "leve"
# <br>"N2": sueño "intermedio"
# <br>"N3": sueño "profundo"

# %%
files = os.listdir('DataSujetos/')
files
# Out:
# ['N2_suj6.csv',
#  'N2_suj5.csv',
#  'W_suj1.csv',
#  'N1_suj11.csv',
#  'N1_suj12.csv',
#  'N1_suj13.csv',
#  'N2_suj14.csv',
#  'N2_suj7.csv',
#  'N2_suj13.csv',
#  'N2_suj4.csv',
#  'N2_suj2.csv',
#  'W_suj12.csv',
#  'N3_suj5.csv',
#  'N1_suj1.csv',
#  'N3_suj15.csv',
#  'N3_suj11.csv',
#  'W_suj9.csv',
#  'N1_suj10.csv',
#  'W_suj4.csv',
#  'N1_suj16.csv',
#  'N2_suj16.csv',
#  'W_suj8.csv',
#  'N3_suj8.csv',
#  'W_suj3.csv',
#  'N2_suj8.csv',
#  'N1_suj14.csv',
#  'N3_suj14.csv',
#  'N3_suj9.csv',
#  'N1_suj17.csv',
#  'N3_suj16.csv',
#  'N3_suj1.csv',
#  'N1_suj3.csv',
#  'N3_suj17.csv',
#  'N1_suj2.csv',
#  'W_suj5.csv',
#  'W_suj18.csv',
#  'N2_suj1.csv',
#  'N2_suj10.csv',
#  'N2_suj11.csv',
#  'N1_suj7.csv',
#  'W_suj17.csv',
#  'N2_suj18.csv',
#  'N1_suj5.csv',
#  'N1_suj8.csv',
#  'N2_suj17.csv',
#  'N3_suj2.csv',
#  'W_suj11.csv',
#  'W_suj6.csv',
#  'W_suj2.csv',
#  'N1_suj18.csv',
#  'N3_suj6.csv',
#  'W_suj13.csv',
#  'W_suj7.csv',
#  'N3_suj10.csv',
#  'N1_suj15.csv',
#  'W_suj10.csv',
#  'N3_suj3.csv',
#  'W_suj14.csv',
#  'N1_suj4.csv',
#  'N3_suj12.csv',
#  'N2_suj9.csv',
#  'W_suj16.csv',
#  'N3_suj13.csv',
#  'N2_suj12.csv',
#  'N2_suj15.csv',
#  'N3_suj4.csv',
#  'N2_suj3.csv',
#  'N1_suj6.csv',
#  'N1_suj9.csv',
#  'W_suj15.csv',
#  'N3_suj18.csv',
#  'N3_suj7.csv']

# %% [markdown]
# Obtener archivos correspondientes a la condición "W" unicamente:

# %%
filenames = Path('DataSujetos').glob('W_*.csv')
next(filenames)
# Out:
# PosixPath('DataSujetos/W_suj1.csv')

# %% [markdown]
# # Vamos a analizar el sujeto 1 de la condición W
# Levantamos los datos y los transformamos en una matriz de adyacencia pesada

# %%
filename = './DataSujetos/W_suj1.csv'
df = pd.read_csv(filename, header=None)
matAdyacPesada = df.values
n = matAdyacPesada.shape[0]
matAdyacPesada -= np.diag(np.ones(n))

# %% [markdown]
# Graficamos la matriz de ayacencia pesada

# %%
sns.heatmap(matAdyacPesada)
plt.xlim(0,n)
plt.ylim(0,n)
# Out:
# (0.0, 116.0)

# %% [markdown]
# Le ponemos un umbral "th" para binarizarla hacia una matriz de adyacencia no pesada:

# %%
th = 0.65
matAdyacNoPesada = matAdyacPesada>=th
sns.heatmap(matAdyacNoPesada)
plt.xlim(0,n)
plt.ylim(0,n)
# Out:
# (0.0, 116.0)

# %% [markdown]
# ## Creamos un grafo con la librería Networkx

# %%
G = nx.from_numpy_array(matAdyacNoPesada)

# %% [markdown]
# # Visualizaciones
# Graficamos al grafo con los nodos dispuestos de diferentes formas

# %%
plt.figure(figsize=(8,6))
plt.title('Sin especificar posiciones', fontsize=14)
nx.draw(G, with_labels=True, font_weight='bold')

plt.figure(figsize=(8,6))
plt.title('Con nodos a lo largo de un círculo', fontsize=14)
layout=nx.circular_layout(G)
nx.draw(G,layout, with_labels=True, font_weight='bold')


plt.figure(figsize=(8,6))
plt.title('Con nodos en sus coordenadas cerebrales', fontsize=14)
layout=dict(zip(range(n),np.array([RegionsNames[6].values, RegionsNames[7].values]).T))
nx.draw(G,layout, with_labels=True, linewidths =1)

# %% [markdown]
# # Graficamos el grafo con cada nodo coloreado de acuerdo a su grado (cantidad de enlances que posee)

# %%
degrees = G.degree() # Diccionario con ID de nodo y su grado
nodes = G.nodes()
n_color = np.asarray([degrees[n] for n in nodes])
plt.figure(figsize=(9,6))
plt.title('Con nodos coloreados de acuerdo a su grado', fontsize=14)
layout=dict(zip(range(n),np.array([RegionsNames[6].values, RegionsNames[7].values]).T))
vmin = min(n_color)
vmax = max(n_color)
cmap=plt.cm.Blues
nx.draw(G, layout, node_size=20, node_color=n_color, vmin=vmin, vmax=vmax,cmap=cmap)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin = vmin, vmax=vmax))
plt.colorbar(sm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 12
#      10 nx.draw(G, layout, node_size=20, node_color=n_color, vmin=vmin, vmax=vmax,cmap=cmap)
#      11 sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin = vmin, vmax=vmax))
# ---> 12 plt.colorbar(sm)
#
# File ~/bin/jupyter/lib/python3.11/site-packages/matplotlib/pyplot.py:2326, in colorbar(mappable, cax, ax, **kwargs)
#    2321     if mappable is None:
#    2322         raise RuntimeError('No mappable was found to use for colorbar '
#    2323                            'creation. First define a mappable such as '
#    2324                            'an image (with imshow) or a contour set ('
#    2325                            'with contourf).')
# -> 2326 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2327 return ret
#
# File ~/bin/jupyter/lib/python3.11/site-packages/matplotlib/figure.py:1285, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1283 if cax is None:
#    1284     if ax is None:
# -> 1285         raise ValueError(
#    1286             'Unable to determine Axes to steal space for Colorbar. '
#    1287             'Either provide the *cax* argument to use as the Axes for '
#    1288             'the Colorbar, provide the *ax* argument to steal space '
#    1289             'from it, or add *mappable* to an Axes.')
#    1290     fig = (  # Figure of first axes; logic copied from make_axes.
#    1291         [*ax.flat] if isinstance(ax, np.ndarray)
#    1292         else [*ax] if np.iterable(ax)
#    1293         else [ax])[0].figure
#    1294     current_ax = fig.gca()
#
# ValueError: Unable to determine Axes to steal space for Colorbar. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.

# %% [markdown]
# Cuál es el nodo con más enlaces?

# %%
sortedNodes=sorted(G.degree, key=lambda x: x[1], reverse=True)
print('El nodo con mayor grado es el',sortedNodes[0][0], ', que posee', sortedNodes[0][1], 'enlaces' )
# Out:
# El nodo con mayor grado es el 29 , que posee 53 enlaces

# %% [markdown]
# ## Comparemos dos estados de vigila

# %%
filename = 'DataSujetos/W_suj1.csv'
df = pd.read_csv(filename, header=None)
matAdyacPesadaWake = df.values
n = matAdyacPesadaWake.shape[0]
matAdyacPesadaWake -= np.diag(np.ones(n))

filename = 'DataSujetos/N3_suj1.csv'
df = pd.read_csv(filename, header=None)
matAdyacPesadaSleep = df.values
n = matAdyacPesadaSleep.shape[0]
matAdyacPesadaSleep -= np.diag(np.ones(n))

# %% [markdown]
# Como observamos ambos estados están asociados a diferentes niveles de correlación entre áreas. ¿Cómo compararlos?

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
sns.heatmap(matAdyacPesadaWake,vmin=-.6,vmax=.9)
plt.xlim(0,n)
plt.ylim(0,n)
plt.title('Sujeto despierto')

plt.subplot(133)
sns.heatmap(matAdyacPesadaSleep,vmin=-.6,vmax=.9)
plt.xlim(0,n)
plt.ylim(0,n)
plt.title('Sujeto dormido')
# Out:
# Text(0.5, 1.0, 'Sujeto dormido')

# %% [markdown]
# ## Definamos una función útil para binarizar una matriz de adyacencia pesada en función de a densidades de enlances resultantes

# %%
def density_to_th(W, d):
    n=W.shape[0]
    max_links = (n*(n-1))//2
    tril_idx = np.tril_indices(n,-1)
    c = sorted(np.array(list(W[tril_idx].reshape(-1))), reverse=True)
    return c[int((len(c)-1)*d)]

# %%
densidad=0.1 # comparemos ambos estados con una densidad de enlaces de 10%

plt.figure(figsize=(6,4))

thWake=density_to_th(matAdyacPesadaWake, densidad)
sns.heatmap(matAdyacPesadaWake>=thWake)
plt.xlim(0,n)
plt.ylim(0,n);
plt.title(f'Despierto, binarizado a  {thWake}')
plt.show()

plt.figure(figsize=(6,4))
thSleep=density_to_th(matAdyacPesadaSleep, densidad)
sns.heatmap(matAdyacPesadaSleep>=thSleep)
plt.xlim(0,n)
plt.ylim(0,n);
plt.title(f'Dormido, binarizado a  {thSleep}')
# Out:
# Text(0.5, 1.0, 'Dormido, binarizado a  0.57099')

# %% [markdown]
# ## ¿Y la distribución de grados en ambos casos?

# %%
plt.figure(figsize=(6,4))
Gsleep = nx.from_numpy_array(matAdyacPesadaSleep>=thSleep)
degreesSleep = [Gsleep.degree(n) for n in Gsleep.nodes()]
plt.hist(degreesSleep,bins=10,density=True)
plt.xlabel('k')
plt.ylabel('p(k)')
plt.title('Distribucion de grados, durmiendo')


plt.figure(figsize=(6,4))
Gwake = nx.from_numpy_array(matAdyacPesadaWake>=thWake)
degreesWake = [Gwake.degree(n) for n in Gwake.nodes()]
plt.hist(degreesWake,bins=10,density=True)
plt.xlabel('k')
plt.ylabel('p(k)')
plt.title('Distribucion de grados, despierto')
# Out:
# Text(0.5, 1.0, 'Distribucion de grados, despierto')
